# %% [markdown]
# <h1>Funcao retirar random samples para variaveis desbalanceadas</h1>
# <h1>Randomizar peso das variaveis/classes para achar a melhor. Simulacao rapida com amostra aleatoria</h1>
# Organiza essa porra

# %%
import pandas as pd
import matplotlib.pyplot as plot
import sklearn
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from mpl_toolkits.mplot3d import axes3d
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
test = pd.read_csv('titanic/test.csv',index_col = 'PassengerId')

# %%
train = pd.read_csv('titanic/train.csv',index_col = 'passengerid')

# %%
test.columns = test.columns.str.lower()

# %%
test.columns = test.columns.str.lower()

# %%
train.head(5)
# Out:
#              survived  pclass  \
# passengerid
# 1                   0     3.0
# 2                   1     1.0
# 3                   1     3.0
# 4                   1     1.0
# 5                   0     3.0
#
#                                                           name      sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris     male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  Female   38.0
# 3                                       Heikkinen, Miss. Laina    women  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female_  35.0
# 5                                     Allen, Mr. William Henry     male  35.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.head(5)
# Out:
#              survived  pclass  \
# passengerid
# 1                   0     3.0
# 2                   1     1.0
# 3                   1     3.0
# 4                   1     1.0
# 5                   0     3.0
#
#                                                           name      sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris     male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  Female   38.0
# 3                                       Heikkinen, Miss. Laina    women  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female_  35.0
# 5                                     Allen, Mr. William Henry     male  35.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # Table of Contents
# 1. [Tratamento dos dados](#example)
# 2. [Example2](#example2)
# 3. [Third Example](#third-example)

# %% [markdown]
# <div id='1'/>
# <h1>1 Tratamento dos dados </h1>

# %% [markdown]
# <p>Dados a Ajustar<br>
#     Age
#     pclass
#     sex
#     cabin
#     embarked
# </p>

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# pclass      418 non-null int64
# name        418 non-null object
# sex         418 non-null object
# age         332 non-null float64
# sibsp       418 non-null int64
# parch       418 non-null int64
# ticket      418 non-null object
# fare        417 non-null float64
# cabin       91 non-null object
# embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 1 to 363
# Data columns (total 11 columns):
# survived    936 non-null int64
# pclass      927 non-null float64
# name        936 non-null object
# sex         890 non-null object
# age         748 non-null float64
# sibsp       936 non-null int64
# parch       936 non-null int64
# ticket      936 non-null object
# fare        936 non-null float64
# cabin       210 non-null object
# embarked    934 non-null object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 87.8+ KB

# %% [markdown]
# <div id='1.1'/>
# <h1>1.1 Age </h1>

# %%
train['age'] = train.age.fillna(train.age.mean())

# %%
test['age'] = test.age.fillna(test.age.mean())

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 1 to 363
# Data columns (total 11 columns):
# survived    936 non-null int64
# pclass      927 non-null float64
# name        936 non-null object
# sex         890 non-null object
# age         936 non-null float64
# sibsp       936 non-null int64
# parch       936 non-null int64
# ticket      936 non-null object
# fare        936 non-null float64
# cabin       210 non-null object
# embarked    934 non-null object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 87.8+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# pclass      418 non-null int64
# name        418 non-null object
# sex         418 non-null object
# age         418 non-null float64
# sibsp       418 non-null int64
# parch       418 non-null int64
# ticket      418 non-null object
# fare        417 non-null float64
# cabin       91 non-null object
# embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %% [markdown]
# <div id='1.1'/>
# <h1>1.1 pclass </h1>

# %% [markdown]
# <p>Dropando registros vazios
# </p>

# %%
train = train[train.pclass.notnull()]

# %%
test = test[test.pclass.notnull()]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 927 entries, 1 to 363
# Data columns (total 11 columns):
# survived    927 non-null int64
# pclass      927 non-null float64
# name        927 non-null object
# sex         883 non-null object
# age         927 non-null float64
# sibsp       927 non-null int64
# parch       927 non-null int64
# ticket      927 non-null object
# fare        927 non-null float64
# cabin       208 non-null object
# embarked    925 non-null object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 86.9+ KB

# %%
## Obtain it from fare and pclass
cabin = train.loc[:,['cabin','fare','pclass']]

# %%
def get_level(cabin):
    if 'A' in cabin:
        return 1
    if 'B' in cabin:
        return 1
    if 'C' in cabin:
        return 2
    if 'D' in cabin:
        return 2
    if 'E' in cabin:
        return 3
    if 'F' in cabin:
        return 3
    if 'G' in cabin:
        return 3
    if cabin == 'nan':
        return -1
    else:
        return -1

# %%
cabin['level']=cabin.cabin.apply(lambda row : get_level(str(row)))

# %%
cabin = cabin[cabin.pclass.notnull()]

# %%
cabin.count()
# Out:
# cabin     208
# fare      927
# pclass    927
# level     927
# dtype: int64

# %%
plot.plot(cabin[cabin.level != -1].pclass,cabin[cabin.level != -1].fare,'ro')
plot.axis([0,4,0,300])
# Out:
# [0, 4, 0, 300]

# %%
# Impact of pclass on Fare
plot.plot(cabin[cabin.pclass != -1].pclass,cabin[cabin.pclass != -1].fare,'ro')
plot.axis([0,4,0,300])
# Out:
# [0, 4, 0, 300]

# %%
fig = plot.figure()
ax = plot.axes(projection = '3d')
xdata = cabin[cabin.level != -1].pclass
ax.set_xlabel('pclass')
ydata = cabin[cabin.level != -1].fare
ax.set_ylabel('fare')
zdata = cabin[cabin.level != -1].level
ax.set_zlabel('level')
ax.scatter3D(xdata,ydata,zdata,c = zdata)
ax.view_init(0,-90)

# %%
ax.view_init(45,45)
fig

# %%
# 4 people in level 7?
train[train.index.isin(cabin[cabin.level == 7].index.values)]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked]
# Index: []

# %%
train = train.drop_duplicates()

# %%
test = test.drop_duplicates()

# %%
train[train.index.value_counts()>1].sort_index()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [survived, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked]
# Index: []

# %%
# 207 com level != -1
cabinTrainX, cabinTestX, cabinTrainY, cabinTestY = train_test_split(cabin[cabin.level != -1],cabin[cabin.level != -1].level , test_size = 0.25, random_state = 0)

# %%
cabinTrainX.index.value_counts().sort_values(ascending = False)
# Out:
# 24     2
# 111    2
# 138    2
# 270    1
# 4      1
# 773    1
# 263    1
# 777    1
# 11     1
# 524    1
# 269    1
# 783    1
# 541    1
# 2      1
# 276    1
# 858    1
# 537    1
# 540    1
# 782    1
# 258    1
# 573    1
# 32     1
# 63     1
# 807    1
# 298    1
# 299    1
# 300    1
# 816    1
# 306    1
# 797    1
#       ..
# 249    1
# 210    1
# 725    1
# 888    1
# 517    1
# 216    1
# 474    1
# 219    1
# 140    1
# 53     1
# 712    1
# 485    1
# 487    1
# 454    1
# 488    1
# 746    1
# 394    1
# 749    1
# 752    1
# 497    1
# 499    1
# 246    1
# 718    1
# 760    1
# 505    1
# 506    1
# 252    1
# 253    1
# 742    1
# 378    1
# Name: passengerid, Length: 152, dtype: int64

# %%
cabinTrainX = cabinTrainX[['fare','pclass']]

# %%
cabinTestX = cabinTestX[['fare','pclass']]

# %%
cabinTrainX = pd.concat([cabinTrainX,pd.get_dummies(cabinTrainX.pclass,drop_first = True)],axis = 1)

# %%
cabinTestX = pd.concat([cabinTestX,pd.get_dummies(cabinTestX.pclass,drop_first = True)],axis = 1)

# %%
cabinTrainX = cabinTrainX.drop(['pclass'],axis = 1)

# %%
cabinTestX = cabinTestX.drop(['pclass'],axis = 1)

# %%
cabinTrainX.head(5)
# Out:
#                  fare  2.0  3.0
# passengerid
# 682           76.7292    0    0
# 137           26.2833    0    0
# 32           146.5208    0    0
# 206           10.4625    0    1
# 497           78.2667    0    0

# %%
cabinTestX.head(5)
# Out:
#                  fare  2.0  3.0
# passengerid
# 62            80.0000    0    0
# 352           35.0000    0    0
# 175           30.6958    0    0
# 22            13.0000    1    0
# 717          227.5250    0    0

# %%
## KNN START ##

# %%
b = pd.DataFrame(columns = ['k','score'])
score_old = 0
# Without
for i in range(1,10):
    # KNN Regressor
    classifier = KNeighborsClassifier(n_neighbors=i)
    classifier.fit(cabinTrainX,cabinTrainY.values.ravel())
    score_new = classifier.score(cabinTrainX,cabinTrainY.values.ravel())
    b = b.append({'k': i,'score' : score_new},ignore_index = True)
    if score_new > score_old:
        score_old = classifier.score(cabinTrainX,cabinTrainY.values.ravel())
print(score_old)
# Out:
# 0.9096774193548387

# %%
plot.plot(b.k,b.score)

# %%
y_pred = classifier.predict(cabinTestX)

# %%
y_pred
# Out:
# array([1, 1, 1, 3, 2, 2, 2, 2, 3, 2, 1, 2, 3, 3, 1, 2, 2, 3, 1, 1, 2, 3,
#        2, 2, 1, 3, 2, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 1, 3, 2, 2, 1,
#        3, 2, 2, 2, 3, 1, 3, 3], dtype=int64)

# %%
train['level']=train.cabin.apply(lambda row : get_level(str(row)))

# %%
train.level.value_counts().apply(lambda row: 100*row/train.level.count()).sort_index()
# Out:
# -1    77.216611
#  1     6.958474
#  2    10.325477
#  3     5.499439
# Name: level, dtype: float64

# %%
classifier = KNeighborsClassifier(n_neighbors=2)
classifier.fit(cabinTrainX,cabinTrainY.values.ravel())
classifier.score(cabinTrainX,cabinTrainY.values.ravel())
# Out:
# 0.8129032258064516

# %%
y_pred
# Out:
# array([1, 1, 1, 3, 2, 2, 2, 2, 3, 2, 1, 2, 3, 3, 1, 2, 2, 3, 1, 1, 2, 3,
#        2, 2, 1, 3, 2, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 1, 3, 2, 2, 1,
#        3, 2, 2, 2, 3, 1, 3, 3], dtype=int64)

# %%
cabinTestY.head(5)
# Out:
# passengerid
# 62     1
# 352    2
# 175    1
# 22     2
# 717    2
# Name: level, dtype: int64

# %%
print(confusion_matrix(cabinTestY, y_pred))
print(classification_report(cabinTestY, y_pred))
# Out:
# [[ 6  9  1]
#  [ 7 13  3]
#  [ 2  3  8]]
#               precision    recall  f1-score   support
#
#            1       0.40      0.38      0.39        16
#            2       0.52      0.57      0.54        23
#            3       0.67      0.62      0.64        13
#
#     accuracy                           0.52        52
#    macro avg       0.53      0.52      0.52        52
# weighted avg       0.52      0.52      0.52        52

# %%
## KNN FINISH ##

# %%
## RANDOM FOREST START ##

# %%
rf_classifier = RandomForestClassifier(n_estimators= 20,criterion='entropy')

# %%
rf_classifier.fit(cabinTrainX,cabinTrainY.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rf_classifier.predict(cabinTestX)

# %%
print(confusion_matrix(cabinTestY.values, y_pred))
print(classification_report(cabinTestY.values, y_pred))
# Out:
# [[13  3  0]
#  [ 5 17  1]
#  [ 3  4  6]]
#               precision    recall  f1-score   support
#
#            1       0.62      0.81      0.70        16
#            2       0.71      0.74      0.72        23
#            3       0.86      0.46      0.60        13
#
#     accuracy                           0.69        52
#    macro avg       0.73      0.67      0.68        52
# weighted avg       0.72      0.69      0.69        52

# %%
b = pd.DataFrame(columns = ['k','score'])
for i in range(1,60):
    # KNN Regressor
    rf_classifier = RandomForestClassifier(n_estimators= i,criterion='entropy')
    rf_classifier.fit(cabinTrainX,cabinTrainY.values.ravel())
    score_new = rf_classifier.score(cabinTrainX,cabinTrainY.values.ravel())
    b = b.append({'k': i,'score' : score_new},ignore_index = True)
    if score_new > score_old:
        score_old = classifier.score(cabinTrainX,cabinTrainY.values.ravel())
print(score_old)
# Out:
# 0.8129032258064516

# %%
plot.scatter(b.k,b.score)

# %%
rf_classifier = RandomForestClassifier(n_estimators= 60,criterion='entropy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-948-ec7b356b23a1> in <module>
# ----> 1 rf_classifier = RandomForestClassifier(n_estimators= 60,criterion='entropy',multi_class = 'ovr')
#
# TypeError: __init__() got an unexpected keyword argument 'multi_class'

# %%
rf_classifier.fit(cabinTrainX,cabinTrainY.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=60,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rf_classifier.predict(cabinTestX)

# %%
print(confusion_matrix(cabinTestY.values, y_pred))
print(classification_report(cabinTestY.values, y_pred))
# Out:
# [[13  3  0]
#  [ 3 19  1]
#  [ 1  4  8]]
#               precision    recall  f1-score   support
#
#            1       0.76      0.81      0.79        16
#            2       0.73      0.83      0.78        23
#            3       0.89      0.62      0.73        13
#
#     accuracy                           0.77        52
#    macro avg       0.79      0.75      0.76        52
# weighted avg       0.78      0.77      0.77        52

# %%
rf_classifier.score(cabinTrainX,cabinTrainY.values.ravel())
# Out:
# 0.9225806451612903

# %%
## LOGISTIC REGRESSION START ##

# %%
lr_classifier = LogisticRegression(multi_class = 'ovr', solver = 'lbfgs', class_weight = 'balanced' )

# %%
lr_classifier.fit(cabinTrainX,cabinTrainY)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='ovr', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr_classifier.predict(cabinTestX)

# %%
print(confusion_matrix(cabinTestY.values, y_pred))
print(classification_report(cabinTestY.values, y_pred, output_dict = True))
# Out:
# [[ 6  9  1]
#  [11 11  1]
#  [ 0  8  5]]
# {'1': {'precision': 0.35294117647058826, 'recall': 0.375, 'f1-score': 0.3636363636363636, 'support': 16}, '2': {'precision': 0.39285714285714285, 'recall': 0.4782608695652174, 'f1-score': 0.4313725490196078, 'support': 23}, '3': {'precision': 0.7142857142857143, 'recall': 0.38461538461538464, 'f1-score': 0.5, 'support': 13}, 'accuracy': 0.4230769230769231, 'macro avg': {'precision': 0.4866946778711485, 'recall': 0.4126254180602007, 'f1-score': 0.43166963755199045, 'support': 52}, 'weighted avg': {'precision': 0.4609324499030381, 'recall': 0.4230769230769231, 'f1-score': 0.4276875085698615, 'support': 52}}

# %%
print(confusion_matrix(cabinTestY.values, y_pred))
rf_report = classification_report(cabinTestY.values, y_pred, output_dict = True)
# Out:
# [[ 6  9  1]
#  [11 11  1]
#  [ 0  8  5]]

# %% [markdown]
# # Machine learning do Machine learning

# %%
rf_report.get("1").get("f1-score")
# Out:
# 0.3636363636363636

# %%
## LOGISTIC REGRESSION END ##

# %%
# Returning results to data without level
train_2 = train[train.level == -1][['pclass','fare']]

# %%
# Ignoring few null pclass...
train_2 = train_2[train_2.pclass.notnull()]

# %%
train_2.head(5)
# Out:
#              pclass     fare
# passengerid
# 1               3.0   7.2500
# 3               3.0   7.9250
# 5               3.0   8.0500
# 6               3.0   8.4583
# 8               3.0  21.0750

# %%
train_2 = pd.concat([train_2,pd.get_dummies(train_2.pclass,drop_first = True)],axis = 1)

# %%
train_2 = train_2.drop(['pclass'],axis = 1)

# %%
train_2.head(5)
# Out:
#                 fare  2.0  3.0
# passengerid
# 1             7.2500    0    1
# 3             7.9250    0    1
# 5             8.0500    0    1
# 6             8.4583    0    1
# 8            21.0750    0    1

# %%
# Predicting level where it was null
y_pred_real = rf_classifier.predict(train_2)

# %%
y_pred_real
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3,
#        2, 3, 3, 3, 3, 3, 1, 1, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2,
#        3, 1, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1,
#        3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3,
#        3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3,
#        3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#       dtype=int64)

# %%
pd.Series(cabinTrainX.fare).plot.hist()

# %%
pd.Series(cabinTestX.fare).plot.hist()

# %%
train_2['pred_level'] = y_pred_real

# %%
# Returning it to original data
train_3 = pd.merge(train,train_2[['pred_level']],on='passengerid')

# %%
train_3
# Out:
#              survived  pclass  \
# passengerid
# 1                   0     3.0
# 3                   1     3.0
# 5                   0     3.0
# 6                   0     3.0
# 8                   0     3.0
# 9                   1     3.0
# 10                  1     2.0
# 13                  0     3.0
# 14                  0     3.0
# 15                  0     3.0
# 16                  1     2.0
# 17                  0     3.0
# 18                  1     2.0
# 19                  0     3.0
# 20                  1     3.0
# 21                  0     2.0
# 23                  1     3.0
# 25                  0     3.0
# 26                  1     3.0
# 27                  0     3.0
# 29                  1     3.0
# 30                  0     3.0
# 31                  0     1.0
# 866           42.0      0      0            236852   13.0000   NaN        S
# 867           27.0      1      0     SC/PARIS 2149   13.8583   NaN        C
# 869            NaN      0      0            345777    9.5000   NaN        S
# 870            4.0      1      1            347742   11.1333   NaN        S
# 871           26.0      0      0            349248    7.8958   NaN        S
# 874           47.0      0      0            345765    9.0000   NaN        S
# 875           28.0      1      0         P/PP 3381   24.0000   NaN        C
# 876           15.0      0      0              2667    7.2250   NaN        C
# 877           20.0      0      0              7534    9.8458   NaN        S
# 878           19.0      0      0            349212    7.8958   NaN        S
# 879            NaN      0      0            349217    7.8958   NaN        S
# 881           25.0      0      1            230433   26.0000   NaN        S
# 882           33.0      0      0            349257    7.8958   NaN        S
# 883           22.0      0      0              7552   10.5167   NaN        S
# 884           28.0      0      0  C.A./SOTON 34068   10.5000   NaN        S
# 885           25.0      0      0   SOTON/OQ 392076    7.0500   NaN        S
# 886           39.0      0      5            382652   29.1250   NaN        Q
# 887           27.0      0      0            211536   13.0000   NaN        S
# 889            NaN      1      2        W./C. 6607   23.4500   NaN        S
# 891           32.0      0      0            370376    7.7500   NaN        Q
#
#              level  pred_level
# passengerid
# 1               -1           3
# 3               -1           3
# 5               -1           3
# 6               -1           3
# 8               -1           3
# 9               -1           3
# 10              -1           3
# 13              -1           3
# 14              -1           3
# 15              -1           3
# 16              -1           2
# 17              -1           3
# 18              -1           3
# 19              -1           3
# 20              -1           3
# 21              -1           3
# 23              -1           3
# 25              -1           3
# 26              -1           3
# 27              -1           3
# 29              -1           3
# 30              -1           3
# 31              -1           1
# 33              -1           3
# 34              -1           3
# 35              -1           1
# 37              -1           3
# 38              -1           3
# 39              -1           3
# 40              -1           3
# ...            ...         ...
# 853             -1           3
# 855             -1           3
# 856             -1           3
# 857             -1           2
# 859             -1           3
# 860             -1           3
# 861             -1           3
# 862             -1           3
# 864             -1           3
# 865             -1           3
# 866             -1           3
# 867             -1           2
# 869             -1           3
# 870             -1           3
# 871             -1           3
# 874             -1           3
# 875             -1           3
# 876             -1           3
# 877             -1           3
# 878             -1           3
# 879             -1           3
# 881             -1           3
# 882             -1           3
# 883             -1           3
# 884             -1           3
# 885             -1           3
# 886             -1           3
# 887             -1           3
# 889             -1           3
# 891             -1           3
#
# [681 rows x 13 columns]

# %%
train_3.pred_level.plot.hist()

# %%
train_3 = train_3.drop(['level'], axis = 1)

# %%
train_3.columns.values[11] = 'level'

# %%
train_3.head(5)
# Out:
#              survived  pclass                            name    sex   age  \
# passengerid
# 1                   0     3.0         Braund, Mr. Owen Harris   male  22.0
# 3                   1     3.0          Heikkinen, Miss. Laina  women  26.0
# 5                   0     3.0        Allen, Mr. William Henry   male  35.0
# 6                   0     3.0                Moran, Mr. James   male   NaN
# 8                   0     3.0  Palsson, Master. Gosta Leonard  male    2.0
#
#              sibsp  parch            ticket     fare cabin embarked  level
# passengerid
# 1                1      0         A/5 21171   7.2500   NaN        S      3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S      3
# 5                0      0            373450   8.0500   NaN        S      3
# 6                0      0            330877   8.4583   NaN        Q      3
# 8                3      1            349909  21.0750   NaN        S      3

# %%
train_3.count()
# Out:
# survived    681
# pclass      681
# name        681
# sex         649
# age         523
# sibsp       681
# parch       681
# ticket      681
# fare        681
# cabin         1
# embarked    681
# level       681
# dtype: int64

# %%
train[train.cabin.notnull()].count()
# Out:
# survived    204
# pclass      202
# name        204
# sex         192
# age         185
# sibsp       204
# parch       204
# ticket      204
# fare        204
# cabin       204
# embarked    202
# level       204
# dtype: int64

# %%
train_end = pd.concat([train[train.cabin.notnull()],train_3])

# %%
train_end.count()
# Out:
# survived    885
# pclass      883
# name        885
# sex         841
# age         708
# sibsp       885
# parch       885
# ticket      885
# fare        885
# cabin       205
# embarked    883
# level       885
# dtype: int64

# %%
train_end['age'] = train_end.age.fillna(train_3.age.mean())

# %%
train_end.drop(['cabin'],axis = 1)
# Out:
#              survived  pclass  \
# passengerid
# 2                   1     1.0
# 4                   1     1.0
# 7                   0     1.0
# 11                  1     3.0
# 12                  1     1.0
# 22                  1     2.0
# 24                  1     1.0
# 28                  0     1.0
# 32                  1     1.0
# 53                  1     1.0
# 55                  0     1.0
# 56                  1     1.0
# 62                  1     1.0
# 63                  0     1.0
# 67                  1     2.0
# 76                  0     3.0
# 89                  1     1.0
# 93                  0     1.0
# 97                  0     1.0
# 98                  1     1.0
# 103                 0     1.0
# 111                 0     1.0
# 119                 0     1.0
# 124                 1     2.0
# 125                 0     1.0
# 129                 1     3.0
# 137                 1     1.0
# 138                 0     1.0
# 140                 0     1.0
# 149                 0     2.0
# ...               ...     ...
# 853                 0     3.0
# 855                 0     2.0
# 856                 1     3.0
# 857                 1     1.0
# 859                 1     3.0
# 860                 0     3.0
# 861                 0     3.0
# 862                 0     2.0
# 864                 0     3.0
# 865                 0     2.0
# 866                 1     2.0
# 867                 1     2.0
# 869                 0     3.0
# 870                 1     3.0
# 871                 0     3.0
# 874                 0     3.0
# 875                 1     2.0
# 876                 1     3.0
# 877                 0     3.0
# 878                 0     3.0
# 879                 0     3.0
# 881                 1     2.0
# 882                 0     3.0
# 883                 0     3.0
# 884                 0     2.0
# 885                 0     3.0
# 886                 0     3.0
# 887                 0     2.0
# 889                 0     3.0
# 891                 0     3.0
#
#                                                           name        sex  \
# passengerid
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    Female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    female_
# 7                                      McCarthy, Mr. Timothy J      male
# 11                             Sandstrom, Miss. Marguerite Rut    Female
# 12                                    Bonnell, Miss. Elizabeth      women
# 22                                       Beesley, Mr. Lawrence       male
# 24                                Sloper, Mr. William Thompson        mal
# 28                              Fortune, Mr. Charles Alexander       male
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)    Female
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)   female
# 55                              Ostby, Mr. Engelhart Cornelius       male
# 56                                           Woolner, Mr. Hugh        mal
# 62                                         Icard, Miss. Amelie        NaN
# 63                                 Harris, Mr. Henry Birkhardt       male
# 67                                Nye, Mrs. (Elizabeth Ramell)   female
# 76                                     Moen, Mr. Sigurd Hansen        man
# 89                                  Fortune, Miss. Mabel Helen    female_
# 97           71.000000      0      0          PC 17754   34.6542        C
# 98           23.000000      0      1          PC 17759   63.3583        C
# 103          21.000000      0      1             35281   77.2875        S
# 111          47.000000      0      0            110465   52.0000        S
# 119          24.000000      0      1          PC 17558  247.5208        C
# 124          32.500000      0      0             27267   13.0000        S
# 125          54.000000      0      1             35281   77.2875        S
# 129          27.916348      1      1              2668   22.3583        C
# 137          19.000000      0      2             11752   26.2833        S
# 138          37.000000      1      0            113803   53.1000        S
# 140          24.000000      0      0          PC 17593   79.2000        C
# 149          36.500000      0      2            230080   26.0000        S
# ...                ...    ...    ...               ...       ...      ...
# 853           9.000000      1      1              2678   15.2458        C
# 855          44.000000      1      0            244252   26.0000        S
# 856          18.000000      0      1            392091    9.3500        S
# 857          45.000000      1      1             36928  164.8667        S
# 859          24.000000      0      3              2666   19.2583        C
# 860          27.916348      0      0              2629    7.2292        C
# 861          41.000000      2      0            350026   14.1083        S
# 862          21.000000      1      0             28134   11.5000        S
# 864          27.916348      8      2          CA. 2343   69.5500        S
# 865          24.000000      0      0            233866   13.0000        S
# 866          42.000000      0      0            236852   13.0000        S
# 867          27.000000      1      0     SC/PARIS 2149   13.8583        C
# 869          27.916348      0      0            345777    9.5000        S
# 870           4.000000      1      1            347742   11.1333        S
# 871          26.000000      0      0            349248    7.8958        S
# 874          47.000000      0      0            345765    9.0000        S
# 875          28.000000      1      0         P/PP 3381   24.0000        C
# 876          15.000000      0      0              2667    7.2250        C
# 877          20.000000      0      0              7534    9.8458        S
# 878          19.000000      0      0            349212    7.8958        S
# 879          27.916348      0      0            349217    7.8958        S
# 881          25.000000      0      1            230433   26.0000        S
# 882          33.000000      0      0            349257    7.8958        S
# 883          22.000000      0      0              7552   10.5167        S
# 884          28.000000      0      0  C.A./SOTON 34068   10.5000        S
# 885          25.000000      0      0   SOTON/OQ 392076    7.0500        S
# 886          39.000000      0      5            382652   29.1250        Q
# 887          27.000000      0      0            211536   13.0000        S
# 889          27.916348      1      2        W./C. 6607   23.4500        S
# 891          32.000000      0      0            370376    7.7500        Q
#
#              level
# passengerid
# 2                2
# 4                2
# 7                3
# 11               3
# 12               2
# 22               2
# 24               1
# 28               2
# 32               1
# 53               2
# 55               1
# 56               2
# 62               1
# 63               2
# 67               3
# 76               3
# 89               2
# 93               3
# 97               1
# 98               2
# 103              2
# 111              2
# 119              1
# 124              3
# 125              2
# 129              3
# 137              2
# 138              2
# 140              1
# 149              3
# ...            ...
# 853              3
# 855              3
# 856              3
# 857              2
# 859              3
# 860              3
# 861              3
# 862              3
# 864              3
# 865              3
# 866              3
# 867              2
# 869              3
# 870              3
# 871              3
# 874              3
# 875              3
# 876              3
# 877              3
# 878              3
# 879              3
# 881              3
# 882              3
# 883              3
# 884              3
# 885              3
# 886              3
# 887              3
# 889              3
# 891              3
#
# [885 rows x 11 columns]

# %%
train_end = train_end.drop(['cabin'],axis = 1)

# %%
train_end.count()
# Out:
# survived    885
# pclass      883
# name        885
# sex         841
# age         885
# sibsp       885
# parch       885
# ticket      885
# fare        885
# embarked    883
# level       885
# dtype: int64

# %%
train_end.sex = train_end.sex.str.strip()

# %%
train_end
# Out:
#              survived  pclass  \
# passengerid
# 2                   1     1.0
# 4                   1     1.0
# 7                   0     1.0
# 11                  1     3.0
# 12                  1     1.0
# 22                  1     2.0
# 24                  1     1.0
# 28                  0     1.0
# 32                  1     1.0
# 53                  1     1.0
# 55                  0     1.0
# 56                  1     1.0
# 62                  1     1.0
# 63                  0     1.0
# 67                  1     2.0
# 76                  0     3.0
# 89                  1     1.0
# 93                  0     1.0
# 97                  0     1.0
# 98                  1     1.0
# 103                 0     1.0
# 111                 0     1.0
# 119                 0     1.0
# 124                 1     2.0
# 125                 0     1.0
# 129                 1     3.0
# 137                 1     1.0
# 138                 0     1.0
# 140                 0     1.0
# 149                 0     2.0
# ...               ...     ...
# 853                 0     3.0
# 855                 0     2.0
# 856                 1     3.0
# 857                 1     1.0
# 859                 1     3.0
# 860                 0     3.0
# 861                 0     3.0
# 862                 0     2.0
# 864                 0     3.0
# 865                 0     2.0
# 866                 1     2.0
# 867                 1     2.0
# 869                 0     3.0
# 870                 1     3.0
# 871                 0     3.0
# 874                 0     3.0
# 875                 1     2.0
# 876                 1     3.0
# 877                 0     3.0
# 878                 0     3.0
# 879                 0     3.0
# 881                 1     2.0
# 882                 0     3.0
# 883                 0     3.0
# 884                 0     2.0
# 885                 0     3.0
# 886                 0     3.0
# 887                 0     2.0
# 889                 0     3.0
# 891                 0     3.0
#
#                                                           name      sex  \
# passengerid
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female_
# 7                                      McCarthy, Mr. Timothy J     male
# 11                             Sandstrom, Miss. Marguerite Rut   Female
# 12                                    Bonnell, Miss. Elizabeth    women
# 22                                       Beesley, Mr. Lawrence     male
# 24                                Sloper, Mr. William Thompson      mal
# 28                              Fortune, Mr. Charles Alexander     male
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)   Female
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)   female
# 55                              Ostby, Mr. Engelhart Cornelius     male
# 56                                           Woolner, Mr. Hugh      mal
# 62                                         Icard, Miss. Amelie      NaN
# 63                                 Harris, Mr. Henry Birkhardt     male
# 67                                Nye, Mrs. (Elizabeth Ramell)   female
# 76                                     Moen, Mr. Sigurd Hansen      man
# 89                                  Fortune, Miss. Mabel Helen  female_
# 93                                 Chaffee, Mr. Herbert Fuller      man
# 97                                   Goldschmidt, Mr. George B     male
# 98                             Greenfield, Mr. William Bertram     male
# 103                                  White, Mr. Richard Frasar      man
# 111                             Porter, Mr. Walter Chamberlain     male
# 119                                   Baxter, Mr. Quigg Edmond     Male
# 124                                        Webber, Miss. Susan    woman
# 125                                White, Mr. Percival Wayland      man
# 129                                          Peter, Miss. Anna   female
# 137                               Newsom, Miss. Helen Monypeny   female
# 138                                Futrelle, Mr. Jacques Heath     male
# 140                                         Giglio, Mr. Victor      mal
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")      man
# ...                                                        ...      ...
# 853                                    Boulos, Miss. Nourelain    women
# 855              Carter, Mrs. Ernest Courtenay (Lilian Hughes)    woman
# 856                                 Aks, Mrs. Sam (Leah Rosen)  female_
# 857                 Wick, Mrs. George Dennick (Mary Hitchcock
# 855          44.000000      1      0            244252   26.0000        S
# 856          18.000000      0      1            392091    9.3500        S
# 857          45.000000      1      1             36928  164.8667        S
# 859          24.000000      0      3              2666   19.2583        C
# 860          27.916348      0      0              2629    7.2292        C
# 861          41.000000      2      0            350026   14.1083        S
# 862          21.000000      1      0             28134   11.5000        S
# 864          27.916348      8      2          CA. 2343   69.5500        S
# 865          24.000000      0      0            233866   13.0000        S
# 866          42.000000      0      0            236852   13.0000        S
# 867          27.000000      1      0     SC/PARIS 2149   13.8583        C
# 869          27.916348      0      0            345777    9.5000        S
# 870           4.000000      1      1            347742   11.1333        S
# 871          26.000000      0      0            349248    7.8958        S
# 874          47.000000      0      0            345765    9.0000        S
# 875          28.000000      1      0         P/PP 3381   24.0000        C
# 876          15.000000      0      0              2667    7.2250        C
# 877          20.000000      0      0              7534    9.8458        S
# 878          19.000000      0      0            349212    7.8958        S
# 879          27.916348      0      0            349217    7.8958        S
# 881          25.000000      0      1            230433   26.0000        S
# 882          33.000000      0      0            349257    7.8958        S
# 883          22.000000      0      0              7552   10.5167        S
# 884          28.000000      0      0  C.A./SOTON 34068   10.5000        S
# 885          25.000000      0      0   SOTON/OQ 392076    7.0500        S
# 886          39.000000      0      5            382652   29.1250        Q
# 887          27.000000      0      0            211536   13.0000        S
# 889          27.916348      1      2        W./C. 6607   23.4500        S
# 891          32.000000      0      0            370376    7.7500        Q
#
#              level
# passengerid
# 2                2
# 4                2
# 7                3
# 11               3
# 12               2
# 22               2
# 24               1
# 28               2
# 32               1
# 53               2
# 55               1
# 56               2
# 62               1
# 63               2
# 67               3
# 76               3
# 89               2
# 93               3
# 97               1
# 98               2
# 103              2
# 111              2
# 119              1
# 124              3
# 125              2
# 129              3
# 137              2
# 138              2
# 140              1
# 149              3
# ...            ...
# 853              3
# 855              3
# 856              3
# 857              2
# 859              3
# 860              3
# 861              3
# 862              3
# 864              3
# 865              3
# 866              3
# 867              2
# 869              3
# 870              3
# 871              3
# 874              3
# 875              3
# 876              3
# 877              3
# 878              3
# 879              3
# 881              3
# 882              3
# 883              3
# 884              3
# 885              3
# 886              3
# 887              3
# 889              3
# 891              3
#
# [885 rows x 11 columns]

# %%
train_end[(train_end.sex != 'male') & (train_end.sex != 'female')].sex.value_counts()
# Out:
# mal        82
# Male       82
# man        82
# woman      45
# female_    45
# Female     44
# women      43
# Name: sex, dtype: int64

# %%
male_sex = ['Male','mal','man','male']
female_sex = ['woman','female_','Female','women','female']
def fix_sex(sex):
    if sex in male_sex:
        return 'male'
    if sex in female_sex:
        return 'female'
    else:
        return 'fail'

# %%
train_end
# Out:
#              survived  pclass  \
# passengerid
# 2                   1     1.0
# 4                   1     1.0
# 7                   0     1.0
# 11                  1     3.0
# 12                  1     1.0
# 22                  1     2.0
# 24                  1     1.0
# 28                  0     1.0
# 32                  1     1.0
# 53                  1     1.0
# 55                  0     1.0
# 56                  1     1.0
# 62                  1     1.0
# 63                  0     1.0
# 67                  1     2.0
# 865          24.000000      0      0            233866   13.0000        S
# 866          42.000000      0      0            236852   13.0000        S
# 867          27.000000      1      0     SC/PARIS 2149   13.8583        C
# 869          27.916348      0      0            345777    9.5000        S
# 870           4.000000      1      1            347742   11.1333        S
# 871          26.000000      0      0            349248    7.8958        S
# 874          47.000000      0      0            345765    9.0000        S
# 875          28.000000      1      0         P/PP 3381   24.0000        C
# 876          15.000000      0      0              2667    7.2250        C
# 877          20.000000      0      0              7534    9.8458        S
# 878          19.000000      0      0            349212    7.8958        S
# 879          27.916348      0      0            349217    7.8958        S
# 881          25.000000      0      1            230433   26.0000        S
# 882          33.000000      0      0            349257    7.8958        S
# 883          22.000000      0      0              7552   10.5167        S
# 884          28.000000      0      0  C.A./SOTON 34068   10.5000        S
# 885          25.000000      0      0   SOTON/OQ 392076    7.0500        S
# 886          39.000000      0      5            382652   29.1250        Q
# 887          27.000000      0      0            211536   13.0000        S
# 889          27.916348      1      2        W./C. 6607   23.4500        S
# 891          32.000000      0      0            370376    7.7500        Q
#
#              level
# passengerid
# 2                2
# 4                2
# 7                3
# 11               3
# 12               2
# 22               2
# 24               1
# 28               2
# 32               1
# 53               2
# 55               1
# 56               2
# 62               1
# 63               2
# 67               3
# 76               3
# 89               2
# 93               3
# 97               1
# 98               2
# 103              2
# 111              2
# 119              1
# 124              3
# 125              2
# 129              3
# 137              2
# 138              2
# 140              1
# 149              3
# ...            ...
# 853              3
# 855              3
# 856              3
# 857              2
# 859              3
# 860              3
# 861              3
# 862              3
# 864              3
# 865              3
# 866              3
# 867              2
# 869              3
# 870              3
# 871              3
# 874              3
# 875              3
# 876              3
# 877              3
# 878              3
# 879              3
# 881              3
# 882              3
# 883              3
# 884              3
# 885              3
# 886              3
# 887              3
# 889              3
# 891              3
#
# [885 rows x 11 columns]

# %%
train_end['sex'] = train_end.sex.apply(lambda row: fix_sex(row))

# %%
train_end.sex.value_counts()
# Out:
# male      544
# female    297
# fail       44
# Name: sex, dtype: int64

# %%
train_end['new_sex'] = train_end.name.apply(lambda name: name.split(',')[1].split('.')[0].strip())

# %%
relacao_titulo_sex = {
    "Capt":       "male",
    "Col":        "male",
    "Major":      "male",
    "Jonkheer":   "male",
    "Don":        "male",
    "Sir" :       "male",
    "Dr":         "male",
    "Rev":        "male",
    "the Countess":"female",
    "Dona":       "female",
    "Mme":        "female",
    "Mlle":       "female",
    "Ms":         "female",
    "Mr" :        "male",
    "Mrs" :       "female",
    "Miss" :      "female",
    "Master" :    "male",
    "Lady" :      "female"
}

#Mapeamento da nova coluna pelo dicionário criado acima
train_end.new_sex = train_end.new_sex.map(relacao_titulo_sex)

# %%
train_end = train_end.drop(['sex'],axis = 1)

# %%
train_end = train_end[train_end.embarked.notnull()]

# %%
train_end = train_end[train_end.pclass.notnull()]

# %%
train_end.count()
# Out:
# survived    881
# pclass      881
# name        881
# age         881
# sibsp       881
# parch       881
# ticket      881
# fare        881
# embarked    881
# level       881
# new_sex     881
# dtype: int64
